# %% [markdown]
# ### Data manipulation example
#
# We read in a SPLICE dataset and format it ready for inclusion in our NN model.
# Where there is no transaction in a development period, that development period with have no record. Settled claims are also not included.
#
# Steps:
#
# 1. Read in the data
# 2. Create additional variables
# 3. Apply cutoff
# 4. Make sure there is one record for every development period
# 5. Create variables and define which ones you want to use in the model
# 6. Create train and test datasets

# %%
#pip install chainladder

import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

import chainladder as cl

import torch
import torch.nn as nn
from torch.nn import functional as F

# %%
dirname="/home/nigel/git/MLR_working_party/01_data/"
filename="data_origframework_nofills_nosttl.csv"

pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# ### 1. Read in the data from SPLICE
# Here we just use the paid data. Case estimate data is also available in the incurred_1.csv file but we do not use it here

# %%
transactions = pd.read_csv(
    f"https://raw.githubusercontent.com/agi-lab/SPLICE/main/datasets/complexity_1/payment_1.csv"
)
transactions
# Out:
#        Unnamed: 0  claim_no  pmt_no  occurrence_period  occurrence_time  \
# 0               1         1       1                  1             0.73
# 1               2         1       2                  1             0.73
# 2               3         1       3                  1             0.73
# 3               4         1       4                  1             0.73
# 4               5         1       5                  1             0.73
# ...           ...       ...     ...                ...              ...
# 19317       19318      3663       2                 40            39.87
# 19318       19319      3663       3                 40            39.87
# 19319       19320      3663       4                 40            39.87
# 19320       19321      3663       5                 40            39.87
# 19321       19322      3663       6                 40            39.87
#
#        claim_size  notidel  setldel  payment_time  payment_period  \
# 0      232,310.09     0.66    23.21          5.33               6
# 1      232,310.09     0.66    23.21         10.09              11
# 2      232,310.09     0.66    23.21         18.02              19
# 3      232,310.09     0.66    23.21         22.82              23
# 4      232,310.09     0.66    23.21         24.61              25
# ...           ...      ...      ...           ...             ...
# 19317   40,653.72     2.29    10.67         46.40              47
# 19318   40,653.72     2.29    10.67         48.45              49
# 19319   40,653.72     2.29    10.67         50.24              51
# 19320   40,653.72     2.29    10.67         51.76              52
# 19321   40,653.72     2.29    10.67         52.84              53
#
#        payment_size  payment_inflated  payment_delay
# 0         13,226.34         13,226.34           3.93
# 1         15,685.86         15,685.86           4.76
# 2         14,643.28         14,643.28           7.93
# 3        170,041.89        170,041.89           4.79
# 4         18,712.71         18,712.71           1.79
# ...             ...               ...            ...
# 19317      2,213.88          2,213.88           1.84
# 19318      2,292.75          2,292.75           2.06
# 19319      2,367.32          2,367.32           1.78
# 19320     28,576.07         28,576.07           1.52
# 19321      2,585.46          2,585.46           1.08
#
# [19322 rows x 13 columns]

# %% [markdown]
# ### 2. Create additional variables

# %%
transactions["noti_period"] = np.ceil(transactions["occurrence_time"] + transactions["notidel"]).astype('int')
transactions["settle_period"] = np.ceil(transactions["occurrence_time"] + transactions["notidel"] + transactions["setldel"]).astype('int')

# %% [markdown]
# ### 3. Apply cutoff

# %%
# Apply a maximum development period
maxdev=40

transactions["development_period"] = np.minimum(transactions["payment_period"] - transactions["occurrence_period"], maxdev)  

transactions
# Out:
#        Unnamed: 0  claim_no  pmt_no  occurrence_period  occurrence_time  \
# 0               1         1       1                  1             0.73
# 1               2         1       2                  1             0.73
# 2               3         1       3                  1             0.73
# 3               4         1       4                  1             0.73
# 4               5         1       5                  1             0.73
# ...           ...       ...     ...                ...              ...
# 19317       19318      3663       2                 40            39.87
# 19318       19319      3663       3                 40            39.87
# 19319       19320      3663       4                 40            39.87
# 19320       19321      3663       5                 40            39.87
# 19321       19322      3663       6                 40            39.87
#
#        claim_size  notidel  setldel  payment_time  payment_period  \
# 0      232,310.09     0.66    23.21          5.33               6
# 1      232,310.09     0.66    23.21         10.09              11
# 2      232,310.09     0.66    23.21         18.02              19
# 3      232,310.09     0.66    23.21         22.82              23
# 4      232,310.09     0.66    23.21         24.61              25
# ...           ...      ...      ...           ...             ...
# 19317   40,653.72     2.29    10.67         46.40              47
# 19318   40,653.72     2.29    10.67         48.45              49
# 19319   40,653.72     2.29    10.67         50.24              51
# 19320   40,653.72     2.29    10.67         51.76              52
# 19321   40,653.72     2.29    10.67         52.84              53
#
#        payment_size  payment_inflated  payment_delay  noti_period  \
# 0         13,226.34         13,226.34           3.93            2
# 1         15,685.86         15,685.86           4.76            2
# 2         14,643.28         14,643.28           7.93            2
# 3        170,041.89        170,041.89           4.79            2
# 4         18,712.71         18,712.71           1.79            2
# ...             ...               ...            ...          ...
# 19317      2,213.88          2,213.88           1.84           43
# 19318      2,292.75          2,292.75           2.06           43
# 19319      2,367.32          2,367.32           1.78           43
# 19320     28,576.07         28,576.07           1.52           43
# 19321      2,585.46          2,585.46           1.08           43
#
#        settle_period  development_period
# 0                 25                   5
# 1                 25                  10
# 2                 25                  18
# 3                 25                  22
# 4                 25                  24
# ...              ...                 ...
# 19317             53                   7
# 19318             53                   9
# 19319             53                  11
# 19320             53                  12
# 19321             53                  13
#
# [19322 rows x 16 columns]

# %% [markdown]
# Only include records for a claim that is after the notification period

# %%
#dat = dat.loc[dat.payment_period >= dat.noti_period].copy()
#dat

# %% [markdown]
# ### 5. Create variables and define which ones you want to use in the model

# %%
dat=transactions

# Clean close to zero values
dat["payment_size"] = np.where(abs(dat.payment_size) < 1e-2, 0.0, dat.payment_size)

#    payment_period=lambda df: (df.occurrence_period + df.development_period),
dat["is_settled"]=((dat.occurrence_period + dat.development_period) >= dat.settle_period)

# Cumulative payments
dat["payment_size_cumulative"] = dat[["claim_no", "payment_size"]].groupby('claim_no').cumsum()
dat["log1_paid_cumulative"] = np.log1p(dat.payment_size_cumulative)

dat["pmt_no"] = dat.groupby("claim_no")["pmt_no"].cummax()

dat
# Out:
#        Unnamed: 0  claim_no  pmt_no  occurrence_period  occurrence_time  \
# 0               1         1       1                  1             0.73
# 1               2         1       2                  1             0.73
# 2               3         1       3                  1             0.73
# 3               4         1       4                  1             0.73
# 4               5         1       5                  1             0.73
# ...           ...       ...     ...                ...              ...
# 19317       19318      3663       2                 40            39.87
# 19318       19319      3663       3                 40            39.87
# 19319       19320      3663       4                 40            39.87
# 19320       19321      3663       5                 40            39.87
# 19321       19322      3663       6                 40            39.87
#
#        claim_size  notidel  setldel  payment_time  payment_period  \
# 0      232,310.09     0.66    23.21          5.33               6
# 1      232,310.09     0.66    23.21         10.09              11
# 2      232,310.09     0.66    23.21         18.02              19
# 3      232,310.09     0.66    23.21         22.82              23
# 4      232,310.09     0.66    23.21         24.61              25
# ...           ...      ...      ...           ...             ...
# 19317   40,653.72     2.29    10.67         46.40              47
# 19318   40,653.72     2.29    10.67         48.45              49
# 19319   40,653.72     2.29    10.67         50.24              51
# 19320   40,653.72     2.29    10.67         51.76              52
# 19321   40,653.72     2.29    10.67         52.84              53
#
#        payment_size  payment_inflated  payment_delay  noti_period  \
# 0         13,226.34         13,226.34           3.93            2
# 1         15,685.86         15,685.86           4.76            2
# 2         14,643.28         14,643.28           7.93            2
# 3        170,041.89        170,041.89           4.79            2
# 4         18,712.71         18,712.71           1.79            2
# ...             ...               ...            ...          ...
# 19317      2,213.88          2,213.88           1.84           43
# 19318      2,292.75          2,292.75           2.06           43
# 19319      2,367.32          2,367.32           1.78           43
# 19320     28,576.07         28,576.07           1.52           43
# 19321      2,585.46          2,585.46           1.08           43
#
#        settle_period  development_period  is_settled  payment_size_cumulative  \
# 0                 25                   5       False                13,226.34
# 1                 25                  10       False                28,912.20
# 2                 25                  18       False                43,555.48
# 3                 25                  22       False               213,597.38
# 4                 25                  24        True               232,310.09
# ...              ...                 ...         ...                      ...
# 19317             53                   7       False                 4,832.11
# 19318             53                   9       False                 7,124.86
# 19319             53                  11       False                 9,492.18
# 19320             53                  12       False                38,068.25
# 19321             53                  13        True                40,653.72
#
#        log1_paid_cumulative
# 0                      9.49
# 1                     10.27
# 2                     10.68
# 3                     12.27
# 4                     12.36
# ...                     ...
# 19317                  8.48
# 19318                  8.87
# 19319                  9.16
# 19320                 10.55
# 19321                 10.61
#
# [19322 rows x 19 columns]

# %% [markdown]
# Show records just for an individual claim - here claim_no 1

# %%
dat[dat['claim_no'] == 1]
# Out:
#    Unnamed: 0  claim_no  pmt_no  occurrence_period  occurrence_time  \
# 0           1         1       1                  1             0.73
# 1           2         1       2                  1             0.73
# 2           3         1       3                  1             0.73
# 3           4         1       4                  1             0.73
# 4           5         1       5                  1             0.73
#
#    claim_size  notidel  setldel  payment_time  payment_period  payment_size  \
# 0  232,310.09     0.66    23.21          5.33               6     13,226.34
# 1  232,310.09     0.66    23.21         10.09              11     15,685.86
# 2  232,310.09     0.66    23.21         18.02              19     14,643.28
# 3  232,310.09     0.66    23.21         22.82              23    170,041.89
# 4  232,310.09     0.66    23.21         24.61              25     18,712.71
#
#    payment_inflated  payment_delay  noti_period  settle_period  \
# 0         13,226.34           3.93            2             25
# 1         15,685.86           4.76            2             25
# 2         14,643.28           7.93            2             25
# 3        170,041.89           4.79            2             25
# 4         18,712.71           1.79            2             25
#
#    development_period  is_settled  payment_size_cumulative  \
# 0                   5       False                13,226.34
# 1                  10       False                28,912.20
# 2                  18       False                43,555.48
# 3                  22       False               213,597.38
# 4                  24        True               232,310.09
#
#    log1_paid_cumulative
# 0                  9.49
# 1                 10.27
# 2                 10.68
# 3                 12.27
# 4                 12.36

# %% [markdown]
# Define which variables you want to use in the model
#
# output_field and youtput are also created to define the y variate for use in the model

# %% [markdown]
# ### Only include records for where the claim is not settled

# %%
dat_set = dat.loc[dat.is_settled == True]
#dat[dat['claim_no'] == 1]
dat_set
# Out:
#        Unnamed: 0  claim_no  pmt_no  occurrence_period  occurrence_time  \
# 4               5         1       5                  1             0.73
# 9              10         2       5                  1             0.33
# 15             16         3       6                  1             0.52
# 20             21         4       5                  1             0.74
# 24             25         5       4                  1             0.62
# ...           ...       ...     ...                ...              ...
# 19302       19303      3659       4                 40            39.54
# 19306       19307      3660       4                 40            39.43
# 19310       19311      3661       4                 40            39.36
# 19315       19316      3662       5                 40            39.79
# 19321       19322      3663       6                 40            39.87
#
#         claim_size  notidel  setldel  payment_time  payment_period  \
# 4       232,310.09     0.66    23.21         24.61              25
# 9       237,675.12     0.74    22.15         23.22              24
# 15       83,559.57     0.90     9.83         11.25              12
# 20      227,599.31     0.42    16.91         18.08              19
# 24      119,227.15     1.64     7.72          9.31              10
# ...            ...      ...      ...           ...             ...
# 19302    19,709.37     0.06     6.67         46.28              47
# 19306    37,299.39     0.22     8.87         48.52              49
# 19310 1,104,261.06     0.38    26.52         66.27              67
# 19315    38,973.68     2.12     3.12         45.02              46
# 19321    40,653.72     2.29    10.67         52.84              53
#
#        payment_size  payment_inflated  payment_delay  noti_period  \
# 4         18,712.71         18,712.71           1.79            2
# 9         14,508.98         14,508.98           3.46            2
# 15         7,135.71          7,135.71           0.62            2
# 20        14,522.22         14,522.22           0.92            2
# 24        94,467.44         94,467.44           1.80            3
# ...             ...               ...            ...          ...
# 19302      1,526.06          1,526.06           1.04           40
# 19306      2,974.15          2,974.15           1.45           40
# 19310     88,058.25         88,058.25           2.43           40
# 19315      3,436.12          3,436.12           0.48           42
# 19321      2,585.46          2,585.46           1.08           43
#
#        settle_period  development_period  is_settled  payment_size_cumulative  \
# 4                 25                  24        True               232,310.09
# 9                 24                  23        True               237,675.12
# 15                12                  11        True                83,559.57
# 20                19                  18        True               227,599.31
# 24                10                   9        True               112,184.28
# ...              ...                 ...         ...                      ...
# 19302             47                   7        True                19,709.37
# 19306             49                   9        True                37,299.39
# 19310             67                  27        True             1,104,261.06
# 19315             46                   6        True                38,973.68
# 19321             53                  13        True                40,653.72
#
#        log1_paid_cumulative
# 4                     12.36
# 9                     12.38
# 15                    11.33
# 20                    12.34
# 24                    11.63
# ...                     ...
# 19302                  9.89
# 19306                 10.53
# 19310                 13.91
# 19315                 10.57
# 19321                 10.61
#
# [4060 rows x 19 columns]

# %%
dat = dat.loc[dat.is_settled == False]
#dat[dat['claim_no'] == 1]
dat
# Out:
#        Unnamed: 0  claim_no  pmt_no  occurrence_period  occurrence_time  \
# 0               1         1       1                  1             0.73
# 1               2         1       2                  1             0.73
# 2               3         1       3                  1             0.73
# 3               4         1       4                  1             0.73
# 5               6         2       1                  1             0.33
# ...           ...       ...     ...                ...              ...
# 19316       19317      3663       1                 40            39.87
# 19317       19318      3663       2                 40            39.87
# 19318       19319      3663       3                 40            39.87
# 19319       19320      3663       4                 40            39.87
# 19320       19321      3663       5                 40            39.87
#
#        claim_size  notidel  setldel  payment_time  payment_period  \
# 0      232,310.09     0.66    23.21          5.33               6
# 1      232,310.09     0.66    23.21         10.09              11
# 2      232,310.09     0.66    23.21         18.02              19
# 3      232,310.09     0.66    23.21         22.82              23
# 5      237,675.12     0.74    22.15          3.46               4
# ...           ...      ...      ...           ...             ...
# 19316   40,653.72     2.29    10.67         44.56              45
# 19317   40,653.72     2.29    10.67         46.40              47
# 19318   40,653.72     2.29    10.67         48.45              49
# 19319   40,653.72     2.29    10.67         50.24              51
# 19320   40,653.72     2.29    10.67         51.76              52
#
#        payment_size  payment_inflated  payment_delay  noti_period  \
# 0         13,226.34         13,226.34           3.93            2
# 1         15,685.86         15,685.86           4.76            2
# 2         14,643.28         14,643.28           7.93            2
# 3        170,041.89        170,041.89           4.79            2
# 5         14,014.05         14,014.05           2.38            2
# ...             ...               ...            ...          ...
# 19316      2,618.23          2,618.23           2.40           43
# 19317      2,213.88          2,213.88           1.84           43
# 19318      2,292.75          2,292.75           2.06           43
# 19319      2,367.32          2,367.32           1.78           43
# 19320     28,576.07         28,576.07           1.52           43
#
#        settle_period  development_period  is_settled  payment_size_cumulative  \
# 0                 25                   5       False                13,226.34
# 1                 25                  10       False                28,912.20
# 2                 25                  18       False                43,555.48
# 3                 25                  22       False               213,597.38
# 5                 24                   3       False                14,014.05
# ...              ...                 ...         ...                      ...
# 19316             53                   5       False                 2,618.23
# 19317             53                   7       False                 4,832.11
# 19318             53                   9       False                 7,124.86
# 19319             53                  11       False                 9,492.18
# 19320             53                  12       False                38,068.25
#
#        log1_paid_cumulative
# 0                      9.49
# 1                     10.27
# 2                     10.68
# 3                     12.27
# 5                      9.55
# ...                     ...
# 19316                  7.87
# 19317                  8.48
# 19318                  8.87
# 19319                  9.16
# 19320                 10.55
#
# [15262 rows x 19 columns]

# %%
# Potential features for model later:
data_cols = [
    "claim_no",
    "occurrence_time", 
    "notidel", 
    "development_period", 
    "pmt_no",
    "log1_paid_cumulative",
]

list_of_features = data_cols
output_field = ["claim_size"]
youtput="claim_size"

dat.loc[:, data_cols + [youtput]]
#dat.loc[:, list_of_features + output_field]
# Out:
#        claim_no  occurrence_time  notidel  development_period  pmt_no  \
# 0             1             0.73     0.66                   5       1
# 1             1             0.73     0.66                  10       2
# 2             1             0.73     0.66                  18       3
# 3             1             0.73     0.66                  22       4
# 5             2             0.33     0.74                   3       1
# ...         ...              ...      ...                 ...     ...
# 19316      3663            39.87     2.29                   5       1
# 19317      3663            39.87     2.29                   7       2
# 19318      3663            39.87     2.29                   9       3
# 19319      3663            39.87     2.29                  11       4
# 19320      3663            39.87     2.29                  12       5
#
#        log1_paid_cumulative  claim_size
# 0                      9.49  232,310.09
# 1                     10.27  232,310.09
# 2                     10.68  232,310.09
# 3                     12.27  232,310.09
# 5                      9.55  237,675.12
# ...                     ...         ...
# 19316                  7.87   40,653.72
# 19317                  8.48   40,653.72
# 19318                  8.87   40,653.72
# 19319                  9.16   40,653.72
# 19320                 10.55   40,653.72
#
# [15262 rows x 7 columns]

# %% [markdown]
# ## 6. Create train and test datasets.
# We provide three types of indicators here for reference, but in our NN example we only use train_ind
#
# * train_ind creates a split by claim - 'rectangular data'
# * train_ind_time is what you would use if you wanted to split the datasets by calendar period
# * cv_ind is what you might use if you were doing cross validation

# %%
cutoff=maxdev

dat["train_ind"] = (dat.claim_no % 10 >= 4)
dat["train_ind_time"] = (dat.payment_period <= cutoff)
dat["cv_ind"] = dat.payment_period % 5
dat
# Out:
# <positron-console-cell-11>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <positron-console-cell-11>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <positron-console-cell-11>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#        Unnamed: 0  claim_no  pmt_no  occurrence_period  occurrence_time  \
# 0               1         1       1                  1             0.73
# 1               2         1       2                  1             0.73
# 2               3         1       3                  1             0.73
# 3               4         1       4                  1             0.73
# 5               6         2       1                  1             0.33
# ...           ...       ...     ...                ...              ...
# 19316       19317      3663       1                 40            39.87
# 19317       19318      3663       2                 40            39.87
# 19318       19319      3663       3                 40            39.87
# 19319       19320      3663       4                 40            39.87
# 19320       19321      3663       5                 40            39.87
#
#        claim_size  notidel  setldel  payment_time  payment_period  ...  \
# 0      232,310.09     0.66    23.21          5.33               6  ...
# 1      232,310.09     0.66    23.21         10.09              11  ...
# 2      232,310.09     0.66    23.21         18.02              19  ...
# 3      232,310.09     0.66    23.21         22.82              23  ...
# 5      237,675.12     0.74    22.15          3.46               4  ...
# ...           ...      ...      ...           ...             ...  ...
# 19316   40,653.72     2.29    10.67         44.56              45  ...
# 19317   40,653.72     2.29    10.67         46.40              47  ...
# 19318   40,653.72     2.29    10.67         48.45              49  ...
# 19319   40,653.72     2.29    10.67         50.24              51  ...
# 19320   40,653.72     2.29    10.67         51.76              52  ...
#
#        payment_delay  noti_period  settle_period  development_period  \
# 0               3.93            2             25                   5
# 1               4.76            2             25                  10
# 2               7.93            2             25                  18
# 3               4.79            2             25                  22
# 5               2.38            2             24                   3
# ...              ...          ...            ...                 ...
# 19316           2.40           43             53                   5
# 19317           1.84           43             53                   7
# 19318           2.06           43             53                   9
# 19319           1.78           43             53                  11
# 19320           1.52           43             53                  12
#
#        is_settled  payment_size_cumulative  log1_paid_cumulative  train_ind  \
# 0           False                13,226.34                  9.49      False
# 1           False                28,912.20                 10.27      False
# 2           False                43,555.48                 10.68      False
# 3           False               213,597.38                 12.27      False
# 5           False                14,014.05                  9.55      False
# ...           ...                      ...                   ...        ...
# 19316       False                 2,618.23                  7.87      False
# 19317       False                 4,832.11                  8.48      False
# 19318       False                 7,124.86                  8.87      False
# 19319       False                 9,492.18                  9.16      False
# 19320       False                38,068.25                 10.55      False
#
#        train_ind_time  cv_ind
# 0                True       1
# 1                True       1
# 2                True       4
# 3                True       3
# 5                True       4
# ...               ...     ...
# 19316           False       0
# 19317           False       2
# 19318           False       4
# 19319           False       1
# 19320           False       2
#
# [15262 rows x 22 columns]

# %%
X_train = (dat.loc[(dat.train_ind == 1), list_of_features])
y_train = (dat.loc[(dat.train_ind == 1), youtput])

X_test = (dat.loc[(dat.train_ind == 0), list_of_features])
y_test = (dat.loc[(dat.train_ind == 0), youtput])

X = (dat.loc[:, list_of_features])
y = (dat.loc[:, youtput])

# %%
dat.loc[(dat.train_ind == 1)]
# Out:
#        Unnamed: 0  claim_no  pmt_no  occurrence_period  occurrence_time  \
# 16             17         4       1                  1             0.74
# 17             18         4       2                  1             0.74
# 18             19         4       3                  1             0.74
# 19             20         4       4                  1             0.74
# 21             22         5       1                  1             0.62
# ...           ...       ...     ...                ...              ...
# 19295       19296      3658       2                 40            39.32
# 19296       19297      3658       3                 40            39.32
# 19299       19300      3659       1                 40            39.54
# 19300       19301      3659       2                 40            39.54
# 19301       19302      3659       3                 40            39.54
#
#        claim_size  notidel  setldel  payment_time  payment_period  ...  \
# 16     227,599.31     0.42    16.91          2.69               3  ...
# 17     227,599.31     0.42    16.91          7.48               8  ...
# 18     227,599.31     0.42    16.91         12.25              13  ...
# 19     227,599.31     0.42    16.91         17.16              18  ...
# 21     119,227.15     1.64     7.72          4.30               5  ...
# ...           ...      ...      ...           ...             ...  ...
# 19295  263,001.49     1.51    10.10         46.37              47  ...
# 19296  263,001.49     1.51    10.10         48.55              49  ...
# 19299   19,709.37     0.06     6.67         42.20              43  ...
# 19300   19,709.37     0.06     6.67         44.08              45  ...
# 19301   19,709.37     0.06     6.67         45.23              46  ...
#
#        payment_delay  noti_period  settle_period  development_period  \
# 16              1.53            2             19                   2
# 17              4.79            2             19                   7
# 18              4.76            2             19                  12
# 19              4.91            2             19                  17
# 21              2.04            3             10                   4
# ...              ...          ...            ...                 ...
# 19295           3.41           41             51                   7
# 19296           2.18           41             51                   9
# 19299           2.59           40             47                   3
# 19300           1.88           40             47                   5
# 19301           1.15           40             47                   6
#
#        is_settled  payment_size_cumulative  log1_paid_cumulative  train_ind  \
# 16          False                 9,886.19                  9.20       True
# 17          False                22,944.02                 10.04       True
# 18          False                34,648.16                 10.45       True
# 19          False               213,077.09                 12.27       True
# 21          False                 5,870.76                  8.68       True
# ...           ...                      ...                   ...        ...
# 19295       False                21,720.12                  9.99       True
# 19296       False                33,159.09                 10.41       True
# 19299       False                 2,615.21                  7.87       True
# 19300       False                 4,888.79                  8.49       True
# 19301       False                18,183.31                  9.81       True
#
#        train_ind_time  cv_ind
# 16               True       3
# 17               True       3
# 18               True       3
# 19               True       3
# 21               True       0
# ...               ...     ...
# 19295           False       2
# 19296           False       4
# 19299           False       3
# 19300           False       0
# 19301           False       1
#
# [9113 rows x 22 columns]

# %%
dat.loc[(dat.train_ind == 0)]
# Out:
#        Unnamed: 0  claim_no  pmt_no  occurrence_period  occurrence_time  \
# 0               1         1       1                  1             0.73
# 1               2         1       2                  1             0.73
# 2               3         1       3                  1             0.73
# 3               4         1       4                  1             0.73
# 5               6         2       1                  1             0.33
# ...           ...       ...     ...                ...              ...
# 19316       19317      3663       1                 40            39.87
# 19317       19318      3663       2                 40            39.87
# 19318       19319      3663       3                 40            39.87
# 19319       19320      3663       4                 40            39.87
# 19320       19321      3663       5                 40            39.87
#
#        claim_size  notidel  setldel  payment_time  payment_period  ...  \
# 0      232,310.09     0.66    23.21          5.33               6  ...
# 1      232,310.09     0.66    23.21         10.09              11  ...
# 2      232,310.09     0.66    23.21         18.02              19  ...
# 3      232,310.09     0.66    23.21         22.82              23  ...
# 5      237,675.12     0.74    22.15          3.46               4  ...
# ...           ...      ...      ...           ...             ...  ...
# 19316   40,653.72     2.29    10.67         44.56              45  ...
# 19317   40,653.72     2.29    10.67         46.40              47  ...
# 19318   40,653.72     2.29    10.67         48.45              49  ...
# 19319   40,653.72     2.29    10.67         50.24              51  ...
# 19320   40,653.72     2.29    10.67         51.76              52  ...
#
#        payment_delay  noti_period  settle_period  development_period  \
# 0               3.93            2             25                   5
# 1               4.76            2             25                  10
# 2               7.93            2             25                  18
# 3               4.79            2             25                  22
# 5               2.38            2             24                   3
# ...              ...          ...            ...                 ...
# 19316           2.40           43             53                   5
# 19317           1.84           43             53                   7
# 19318           2.06           43             53                   9
# 19319           1.78           43             53                  11
# 19320           1.52           43             53                  12
#
#        is_settled  payment_size_cumulative  log1_paid_cumulative  train_ind  \
# 0           False                13,226.34                  9.49      False
# 1           False                28,912.20                 10.27      False
# 2           False                43,555.48                 10.68      False
# 3           False               213,597.38                 12.27      False
# 5           False                14,014.05                  9.55      False
# ...           ...                      ...                   ...        ...
# 19316       False                 2,618.23                  7.87      False
# 19317       False                 4,832.11                  8.48      False
# 19318       False                 7,124.86                  8.87      False
# 19319       False                 9,492.18                  9.16      False
# 19320       False                38,068.25                 10.55      False
#
#        train_ind_time  cv_ind
# 0                True       1
# 1                True       1
# 2                True       4
# 3                True       3
# 5                True       4
# ...               ...     ...
# 19316           False       0
# 19317           False       2
# 19318           False       4
# 19319           False       1
# 19320           False       2
#
# [6149 rows x 22 columns]

# %%
import datetime

def map_value_to_date(value: float) -> datetime.date:
    """
    Maps a value in the range [0, 40] to a date between 01/01/2000 and 31/12/2010.

    Args:
        value: The input value (float) to map, expected in the range [0, 40].

    Returns:
        A datetime.date object (only the date, no time).
    """

    # 1. Define the input range (Source)
    X_MIN = 0.0
    X_MAX = 40.0

    # 2. Define the output date range (Target)
    # Note: We still define the time bounds (00:00:00 to 23:59:59) for accuracy
    START_DATE = datetime.datetime(2000, 1, 1, 0, 0, 0)
    END_DATE = datetime.datetime(2010, 12, 31, 23, 59, 59)

    # 3. Convert target dates to Unix epoch times
    T_START = START_DATE.timestamp()
    T_END = END_DATE.timestamp()
    T_RANGE = T_END - T_START

    # 5. Linear Interpolation
    normalized_ratio = (value - X_MIN) / (X_MAX - X_MIN)
    mapped_epoch_time = T_START + (normalized_ratio * T_RANGE)

    # 6. Convert the resulting epoch time back to a datetime object
    mapped_datetime = datetime.datetime.fromtimestamp(mapped_epoch_time)
    
    # 7. 💥 AMENDMENT: Return only the date part 💥
    return mapped_datetime.date()

# %%
dat['occurrence_date'] = dat['occurrence_time'].apply(map_value_to_date)
dat['notification_date'] = (dat['occurrence_time']+ dat['notidel']).apply(map_value_to_date)
dat['payment_date'] = dat['payment_time'].apply(map_value_to_date)
dat['settlement_date'] = (dat['occurrence_time']+ dat['notidel']+ dat['setldel']).apply(map_value_to_date)
# Out:
# <positron-console-cell-38>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <positron-console-cell-38>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <positron-console-cell-38>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <positron-console-cell-38>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# Save file to disk

# %%
cl.Triangle(dat.loc[(dat.train_ind == 1)], origin='occurrence_date', development='payment_date', columns=['payment_size'], cumulative = False).grain('OYDY')

#cl.load_sample('quarterly').grain('OYDY')
# Out:
# /home/nigel/git/MLR_working_party/.venv/lib/python3.9/site-packages/chainladder/core/triangle.py:796: FutureWarning: Resampling with a PeriodIndex is deprecated. Cast index to DatetimeIndex before resampling instead.
#   pd.Series(range(len(self.origin)), index=self.origin)
#       1          13           25           37           49           61           73           85           97           109          121  133  145  157  169  181  193  205  217  229  241
# 2000  NaN 258,535.29 1,679,966.15 3,379,761.68 3,371,165.22 4,039,610.48 3,762,410.45 3,397,566.60 1,541,007.62   520,104.30          NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2001  NaN 231,544.79 1,500,160.92 2,766,985.32 5,267,991.41 3,968,971.36 4,361,166.33 5,559,050.94 5,155,673.40 2,154,952.85 1,827,002.00  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2002  NaN 199,972.87 1,783,054.50 2,805,679.87 4,605,241.61 8,342,742.55 4,123,800.89 4,710,989.62 3,219,327.28   722,156.79 2,349,908.47  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2003  NaN 255,177.70 1,583,158.69 3,001,309.23 3,408,810.17 6,209,381.49 3,438,934.57 4,133,384.46 2,009,005.07   233,617.47   542,877.91  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2004  NaN 321,553.91 1,811,089.67 4,036,236.90 3,914,043.84 5,631,342.30 4,311,520.24 1,142,252.30 1,237,667.07 2,142,270.99          NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2005  NaN 340,416.09 1,934,798.66 3,409,589.81 5,345,012.93 4,028,025.90 5,184,897.79 4,111,695.87 4,376,083.84 1,373,823.92          NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2006  NaN 362,459.41 1,272,542.95 2,589,444.31 3,159,741.04 4,864,187.73 4,545,183.64 3,090,955.95   849,786.30          NaN          NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2007  NaN 331,938.58 1,668,113.04 3,291,942.58 5,045,788.18 8,428,769.32 4,405,004.70 4,416,596.24 2,285,445.97 3,131,649.56          NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2008  NaN 260,092.65 1,486,760.08 2,475,399.09 3,913,153.47 6,590,302.70 3,666,225.93 2,953,399.29 1,757,921.07   792,029.83   868,065.49  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2009  NaN 281,146.11 1,547,891.23 2,358,648.29 4,536,719.69 6,912,203.99 4,437,028.86 3,949,124.48 4,122,086.28 1,643,707.63 1,367,191.46  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2010  NaN 263,442.60 1,430,312.49 2,618,539.11 4,388,449.60 4,049,256.05 3,346,718.90 6,083,309.17 2,512,204.44   281,127.57 3,432,568.14  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2011  NaN        NaN          NaN          NaN          NaN          NaN          NaN          NaN          NaN          NaN          NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2012  NaN        NaN          NaN          NaN          NaN          NaN          NaN          NaN          NaN          NaN          NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2013  NaN        NaN          NaN          NaN          NaN          NaN          NaN          NaN          NaN          NaN          NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2014  NaN        NaN          NaN          NaN          NaN          NaN          NaN          NaN          NaN          NaN          NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2015  NaN        NaN          NaN          NaN          NaN          NaN          NaN          NaN          NaN          NaN          NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2016  NaN        NaN          NaN          NaN          NaN          NaN          NaN          NaN          NaN          NaN          NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2017  NaN        NaN          NaN          NaN          NaN          NaN          NaN          NaN          NaN          NaN          NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2018  NaN        NaN          NaN          NaN          NaN          NaN          NaN          NaN          NaN          NaN          NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2019  NaN        NaN          NaN          NaN          NaN          NaN          NaN          NaN          NaN          NaN          NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2020  NaN        NaN          NaN          NaN          NaN          NaN          NaN          NaN          NaN          NaN          NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN

# %%
dat.to_csv(
    dirname + filename
)

# %%
filename
# Out:
# 'data_origframework_nofills_nosttl.csv'
